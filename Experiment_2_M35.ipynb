# %%
import numpy as np
import matplotlib.pyplot as plt
from astropy.io import fits

# %%
M13I = fits.open('frame-i-006585-4-0060.fits')
M13I.info()
# Out:
# Filename: frame-i-006585-4-0060.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      96   (2048, 1489)   float32
#   1                1 ImageHDU         6   (2048,)   float32
#   2                1 BinTableHDU     27   1R x 3C   [49152E, 2048E, 1489E]
#   3                1 BinTableHDU     79   1R x 31C   [J, 3A, J, A, D, D, 2J, J, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, E, E]

# %%
M13I[0].header
# Out:
# SIMPLE  =                    T /
# BITPIX  =                  -32 / 32 bit floating point
# NAXIS   =                    2
# NAXIS1  =                 2048
# NAXIS2  =                 1489
# EXTEND  =                    T /Extensions may be present
# BZERO   =              0.00000 /Set by MRD_SCALE
# BSCALE  =              1.00000 /Set by MRD_SCALE
# TAI     =        4670823156.70 / 1st row Number of seconds since Nov 17 1858
# RA      =            92.180288 / 1st row RA of telescope boresight (deg)
# DEC     =            23.843686 / 1st row Dec of telescope boresight (degrees)
# SPA     =              61.053  / 1st row Cam col position angle wrt N (deg)
# IPA     =             358.521  / 1st row Inst rotator position angle (deg)
# IPARATE =             -0.0025  / 1st row Inst rotator anglr velocity (deg/sec)
# AZ      =            285.23967 / 1st row Azimuth (encoder) of tele (0=N?) (deg)
# ALT     =            66.135619 / 1st row Altitude (encoder) of tele (degrees)
# ...

# %%
M13I[1].header
# Out:
# XTENSION= 'IMAGE   '           /Image Extension created by MWRFITS v1.11
# BITPIX  =                  -32 /
# NAXIS   =                    1 /
# NAXIS1  =                 2048 /
# PCOUNT  =                    0 /
# GCOUNT  =                    1 /

# %%
data = M13I[0].data

# %%
print(type(data))
print(data.shape)
print('Min', np.min(data))
print('Max', np.max(data))
print('Mean', np.mean(data))
print('Std', np.std(data))
# Out:
# <class 'numpy.ndarray'>
# (1489, 2048)
# Min -0.26513672
# Max 139.0
# Mean 0.2944406
# Std 2.1586738

# %%
from matplotlib.colors import LogNorm

plt.imshow(data, cmap="gray", norm=LogNorm())
plt.colorbar()

# %%
M13U = fits.open('frame-u-006585-4-0060.fits')
M13G = fits.open('frame-g-006585-4-0060.fits')

# %%
from astropy.visualization import make_lupton_rgb

# %%
g = M13G[0].data
i = M13I[0].data
u = M13U[0].data

# %%
rgb_default = make_lupton_rgb(i, g, u, stretch=1.5)
plt.imshow(rgb_default)
